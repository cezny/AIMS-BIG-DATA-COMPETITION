# %%
# !pip install pyreadstat
# Out:
# Requirement already satisfied: pyreadstat in /home/cezny/anaconda3/lib/python3.7/site-packages (0.2.8)

# %%
import pandas as pd
import scipy.io
import pyreadstat
import numpy as np
import sklearn
import datetime
import os
import pylab as plt

# %%
Seasonal_files = ['Seasonal Agriculture Survey 2014 Season A Stata', 'Seasonal Agriculture Survey 2014 Season B Stata',
           'Seasonal Agriculture Survey 2014 Season C Stata', 'Seasonal Agriculture Survey 2015 Season A Stata',
            'Seasonal Agriculture Survey 2015 Season B Stata', 'Seasonal Agriculture Survey 2015 Season C Stata', 
           'Seasonal Agriculture Survey 2016 Season A Stata', 'Seasonal Agriculture Survey 2016 Season B Stata',
           'Seasonal Agriculture Survey 2016 Season C Stata', 'Seasonal Agriculture Survey 2017 Stata']

# %%
CFSVA_file = ['CFSVA 2006','CFSVA 2009', 'CFSVA 2012', 'CFSVA 2015']

# %%
def readFileInDictionary(path):
    os.chdir(path)
    output = {}
    for dirpath,dirmanes,filenames in os.walk('.'):
        for file in filenames:
            if file.endswith('.dta'):
                  output[str(file)] = pd.read_stata(str(file))
            elif file.endswith('.sav'):
                  output[str(file)] = pyreadstat.read_sav(str(file))
    os.chdir('/content/drive/My Drive/Food Security')
    return output

# %%
SeasonalOutputData = {}
CFSVAOutputData = {}

# %%
for i in Seasonal_files:
    SeasonalOutputData[str(i)] = readFileInDictionary(str(i))

# %%
# for i in CFSVA_file:
#      CFSVAOutputData[str(i)] = readFileInDictionary(str(i))

# %%
#CFSVAOutputData['CFSVA 2012']['cfsvans-2012-children-mothers-household.sav'][0]
#[1].column_names_to_labels

# %%
#Population_weight = CFSVAOutputData['CFSVA 2012']['cfsvans-2012-children-mothers-household.sav'][0]['FINAL_PopWeight']
# wealth_index = CFSVAOutputData['CFSVA 2012']['cfsvans-2012-children-mothers-household.sav'][0]['NFAC1_1']
# wealth_index
#Population_weight

# %%
# dada = CFSVAOutputData['CFSVA 2012']['cfsvans-2012-children-mothers-household.sav'][0]['fdgrp1_consumed']

# %%
#dada

# %%
print("Current Working Directory " , os.getcwd())
# Out:
# Current Working Directory  /content/drive/My Drive/Food Security/CFSVA 2006

# %%
# data = SeasonalOutputData['Seasonal Agriculture Survey 2014 Season A Stata']['Yield.dta']
# data = data.set_index(['group_crop'])
# data

# %%
# import matplotlib.pyplot as plt 
# data.plot(kind='bar')
# plt.xticks(rotation=90)
# plt.show()

# %%
# data.plot.bar(stacked=True);
# plt.xticks(rotation=90)
# plt.show()

# %%
# dataB = SeasonalOutputData['Seasonal Agriculture Survey 2014 Season B Stata']['Yield.dta']
# dataB = dataB.set_index(['group_crop'])
# dataB

# %%
# dataB.plot.bar(stacked=True);
# plt.xticks(rotation=90)
# plt.show()

# %%
# dataC = SeasonalOutputData['Seasonal Agriculture Survey 2014 Season C Stata']['Yield.dta']
# dataC = dataC.set_index(['group_crop'])
# dataC

# %%
# dataC.plot.bar(stacked=True);
# plt.xticks(rotation=85)
# plt.show()

# %%
# data1A = SeasonalOutputData['Seasonal Agriculture Survey 2015 Season A Stata']['Yield.dta']
# data1A = data1A.set_index(['group_crop'])
# data1A

# %%
# data1A.plot.bar(stacked=True);
# plt.xticks(rotation=85)
# plt.show()

# %%
# data1B = SeasonalOutputData['Seasonal Agriculture Survey 2015 Season B Stata']['Yield.dta']
# data1B = data1B.set_index(['group_crop'])
# data1B

# %%
# data1B.plot.bar(stacked=True);
# plt.xticks(rotation=85)
# plt.show()

# %%
# data1C = SeasonalOutputData['Seasonal Agriculture Survey 2015 Season C Stata']['Yield.dta']
# data1C = data1C.set_index(['group_crop'])
# data1C

# %%
# data1C.plot.bar(stacked=True);
# plt.xticks(rotation=85)
# plt.show()

# %%
# data2A = SeasonalOutputData['Seasonal Agriculture Survey 2016 Season B Stata']['Yield.dta']
# data2A = data2A.set_index(['group_crop'])
# data2A

# %%
# data2A.plot.bar(stacked=True);
# plt.xticks(rotation=85)
# plt.show()

# %%
# data111 = SeasonalOutputData['Seasonal Agriculture Survey 2015 Season A Stata']['farmq_part0.dta']
# data111

# %%
esoko = pd.read_csv('esoko.csv')
esoko
# Out:
#         Province District  ... Average Price                   Date
# 0       Northern  GICUMBI  ...         700.0             06/22/2019
# 1       Northern  GICUMBI  ...         425.0             06/22/2019
# 2       Northern  GICUMBI  ...         637.0             06/22/2019
# 3       Northern  GICUMBI  ...         500.0             06/22/2019
# 4       Northern  GICUMBI  ...        1200.0             06/22/2019
# 5       Northern  GICUMBI  ...         917.0             06/22/2019
# 6       Northern  GICUMBI  ...        1000.0             06/22/2019
# 7       Northern  GICUMBI  ...        2333.0             06/22/2019
# 8       Northern  GICUMBI  ...           NaN             06/22/2019
# 9       Northern  GICUMBI  ...           NaN             06/22/2019
# 10      Northern  GICUMBI  ...        9000.0             06/22/2019
# 11      Northern  GICUMBI  ...         300.0             06/22/2019
# 12      Northern  GICUMBI  ...         375.0             06/22/2019
# 13      Northern  GICUMBI  ...         195.0             06/22/2019
# 14      Northern  GICUMBI  ...         200.0             06/22/2019
# 15      Northern  GICUMBI  ...         350.0             06/22/2019
# 16      Northern  GICUMBI  ...         567.0             06/22/2019
# 17      Northern  GICUMBI  ...         900.0             06/22/2019
# 18      Northern  GICUMBI  ...         800.0             06/22/2019
# 19      Northern  GICUMBI  ...         500.0             06/22/2019
# 20      Northern  GICUMBI  ...         600.0             06/22/2019
# 21      Northern  GICUMBI  ...        1267.0             06/22/2019
# 22      Northern  GICUMBI  ...         500.0             06/22/2019
# 23      Northern  GICUMBI  ...         200.0             06/22/2019
# 24      Northern  GICUMBI  ...         700.0             06/22/2019
# 25      Northern  GICUMBI  ...         800.0             06/22/2019
# 26      Northern  GICUMBI  ...         500.0             06/22/2019
# 27      Northern  GICUMBI  ...         350.0             06/22/2019
# 28      Northern  GICUMBI  ...         300.0             06/22/2019
# 29      Northern  GICUMBI  ...         200.0             06/22/2019
# ...          ...      ...  ...           ...                    ...
# 600984   Western  NYABIHU  ...         300.0  10/24/2013 7:15:00 AM
# 600985   Western  NYABIHU  ...         350.0  10/24/2013 7:15:00 AM
# 600986   Western  NYABIHU  ...         300.0  10/24/2013 7:15:00 AM
# 600987   Western  NYABIHU  ...         433.0  10/24/2013 7:15:00 AM
# 600988   Western  NYABIHU  ...         200.0  10/24/2013 7:15:00 AM
# 600989   Western  NYABIHU  ...         190.0  10/24/2013 7:15:00 AM
# 600990   Western  NYABIHU  ...         153.0  10/24/2013 7:15:00 AM
# 600991   Western  NYABIHU  ...         630.0  10/24/2013 7:15:00 AM
# 600992   Western  NYABIHU  ...         650.0  10/24/2013 7:15:00 AM
# 600993   Western  NYABIHU  ...        2800.0  10/24/2013 7:15:00 AM
# 600994   Western  NYABIHU  ...         750.0  10/24/2013 7:15:00 AM
# 600995   Western  NYABIHU  ...         175.0  10/24/2013 7:15:00 AM
# 600996   Western  NYABIHU  ...         600.0  10/24/2013 7:15:00 AM
# 600997   Western  NYABIHU  ...         150.0  10/24/2013 7:15:00 AM
# 600998   Western  NYABIHU  ...         467.0  10/24/2013 7:15:00 AM
# 600999   Western  NYABIHU  ...         400.0  10/24/2013 7:15:00 AM
# 601000   Western  NYABIHU  ...        2400.0  10/24/2013 7:15:00 AM
# 601001   Western  NYABIHU  ...         300.0  10/24/2013 7:15:00 AM
# 601002   Western  NYABIHU  ...         435.0  10/24/2013 7:15:00 AM
# 601003   Western  NYABIHU  ...         800.0  10/24/2013 7:15:00 AM
# 601004   Western  NYABIHU  ...         600.0  10/24/2013 7:15:00 AM
# 601005   Western  NYABIHU  ...         500.0  10/24/2013 7:15:00 AM
# 601006   Western  NYABIHU  ...         300.0  10/24/2013 7:15:00 AM
# 601007   Western  NYABIHU  ...        1000.0  10/24/2013 7:15:00 AM
# 601008   Western  NYABIHU  ...         300.0  10/24/2013 7:15:00 AM
# 601009   Western  NYABIHU  ...         250.0  10/24/2013 7:15:00 AM
# 601010   Western  NYABIHU  ...         500.0  10/24/2013 7:15:00 AM
# 601011   Western  NYABIHU  ...         300.0  10/24/2013 7:15:00 AM
# 601012   Western  NYABIHU  ...        1100.0  10/24/2013 7:15:00 AM
# 601013   Western  NYABIHU  ...         850.0  10/24/2013 7:15:00 AM
#
# [601014 rows x 6 columns]

# %%
def displayCommodityAvargePricePerDistrict(commodityName):
    df = pd.read_csv('esoko.csv')
    df = df.iloc[::-1]
    df = df.drop(['Province', 'Market'], axis=1)#Droping the Province and Market columns
    df = df.loc[df['Commodity']== commodityName]#Selected only one commoduty
    df = df.set_index(['Date'])
    df.groupby('District')['Average Price'].mean().sort_values().plot(kind='barh', figsize=(15,7), stacked = True)
    plt.title("Average price for {} per district ".format(commodityName))
    plt.xlabel("Average price (RWF) ")
    plt.ylabel("Districts ")
    plt.savefig("displayCommodityAvargePricePerDistrict {} .png".format(commodityName))
    plt.show()
    
displayCommodityAvargePricePerDistrict('Ubunyobwa')

# %%
def displayCommoditiesAveragePricesPereachDistrict(districtName):
    df = pd.read_csv('esoko.csv')
    df = df.iloc[::-1]
    df = df.drop(['Province', 'Market'], axis=1)#Droping the Province and Market columns
    df = df.loc[df['District']== districtName.upper() ]#Selected only one district
    df = df.set_index(['Date'])
    df.groupby('Commodity')['Average Price'].mean().sort_values().plot(kind='barh', figsize=(50,47), stacked = True)
    plt.plt.title("Commodities for {} district ".format(districtName))
    plt.xlabel("Average price (RWF) ")
    plt.ylabel("Commodities ")
    plt.savefig("displayCommoditiesAveragePricesPereachDistrict {} .png".format(districtName))
    plt.show()
    
#displayCommoditiesAveragePricesPereachDistrict('nyamasheke')

# %%
Dates_data = esoko['Date'].unique().tolist()
commodity_data = esoko['Commodity'].unique().tolist()
commodity_data
# Out:
# ['Soya',
#  'Ifu-imyumbati',
#  'Ifu-ibigori',
#  'Ifu-amasaka',
#  'Ifu-ibigori-yo-mumahanga',
#  'Umuceli-Asia',
#  'Umuceli-Tz',
#  'Inyama-zinka',
#  'Intama',
#  'Ihene',
#  'Amakara',
#  'Ibigori',
#  'Ibishyimbo',
#  'Igitoki',
#  'Ibirayi',
#  'Inanasi',
#  'Imineke',
#  'Ibinyomoro',
#  'Amatunda',
#  'Indimu',
#  'Mandarine',
#  'Amacunga',
#  'Imyembe',
#  'Epinari',
#  'Sereli',
#  'Urusenda',
#  'Beterave',
#  'Inyanya',
#  'Ibihaza',
#  'Imyumbati',
#  'Ibijumba',
#  'Urunyogwe',
#  'Puwaro',
#  'Puwavuro',
#  'Imiteja',
#  'Karoti',
#  'Dodo',
#  'Tungurusumu',
#  'ibitunguru-bitukura',
#  'Ibitunguru-umweru',
#  'Amasaka',
#  'Amashaza',
#  'Amashu',
#  'inshyushyu',
#  'Ingano',
#  'Ubunyobwa',
#  'Umuceli-RW',
#  'Ifu-ingano',
#  'Ipapayi',
#  'Avoka',
#  'Amapera',
#  'Igi',
#  'Inyama-ihene',
#  'Uruhu-inka',
#  'Uruhu-ihene',
#  'Inkoko',
#  'Isombe',
#  'Ibiringanya',
#  'Ibitoki-inkashi',
#  'Konkombure',
#  'Shufureri',
#  'Ibitonore',
#  'Perisili',
#  'Pome',
#  'Ubuki',
#  'Inyama-ingurube',
#  'Leti',
#  'Ingurube',
#  'Ditane',
#  'Uree',
#  'NPK',
#  'Uruhu-intama',
#  'DAP',
#  'Inyama-intama',
#  'Inka',
#  'Ikimasa',
#  'Imihuhu',
#  'Inkeri',
#  nan,
#  'Atta Comodity']

# %%
commodityDictionary = {commodity_data[i]: i  for i in range(len(commodity_data))}
word = '7/18/2014 6:00:00 AM'

# %%
esokoDistrict = pd.read_csv('esoko.csv', index_col = 'District')
a = str()
#esokoDistrict.loc['GICUMBI']

# %%
def selectByDistrict(districtName):
  districtName = str(districtName).upper()
  esokoDistrict = pd.read_csv('esoko.csv', index_col = 'District')
  return esokoDistrict.loc[districtName]

# %%
nyamasheke = selectByDistrict('nyamasheke')
nyamasheke

# %%
#esokoDistrictGicumbiMarkets = esokoDistrictGicumbi['Market'].unique().todict

# %%
def selectDistrictMarkets(esokoDistrict, marketName):
  esokoDistrictByMarkets = esokoDistrict.set_index('Market')
  return esokoDistrictByMarkets.loc[str(marketName)].get(["Commodity", "Average Price","Date" ])

# %%
def selectDistrictMarketsCommodity(districtMarkets, commodityName):
  esokoDistrictByMarketByCommodity = districtMarkets.set_index("Commodity")
  return esokoDistrictByMarketByCommodity.loc[str(commodityName)]

def getDataPerYear(DistrictMarketsCommodity):
    Data2019 = []
    Data2018 = []
    Data2017 = []
    Data2016 = []
    Data2015 = []
    Data2014 = []
    Data2013 = []

    for i in range(len(DistrictMarketsCommodity['Average Price'])):
        if DistrictMarketsCommodity['Date'].values[i].find('2019') != -1:
            Data2019.append([DistrictMarketsCommodity['Date'].values[i], DistrictMarketsCommodity['Average Price'].values[i] ])

        elif DistrictMarketsCommodity['Date'].values[i].find('2018') != -1:
            Data2018.append([DistrictMarketsCommodity['Date'].values[i], DistrictMarketsCommodity['Average Price'].values[i] ]) 

        elif DistrictMarketsCommodity['Date'].values[i].find('2017') != -1:
            Data2017.append([DistrictMarketsCommodity['Date'].values[i], DistrictMarketsCommodity['Average Price'].values[i] ])

        elif DistrictMarketsCommodity['Date'].values[i].find('2016') != -1:
            Data2016.append([DistrictMarketsCommodity['Date'].values[i], DistrictMarketsCommodity['Average Price'].values[i] ])

        elif DistrictMarketsCommodity['Date'].values[i].find('2015') != -1:
            Data2015.append([DistrictMarketsCommodity['Date'].values[i], DistrictMarketsCommodity['Average Price'].values[i] ])

        elif DistrictMarketsCommodity['Date'].values[i].find('2014') != -1:
            Data2014.append([DistrictMarketsCommodity['Date'].values[i], DistrictMarketsCommodity['Average Price'].values[i] ])

        elif DistrictMarketsCommodity['Date'].values[i].find('2013') != -1:
            Data2013.append([DistrictMarketsCommodity['Date'].values[i], DistrictMarketsCommodity['Average Price'].values[i] ])
   
    return (Data2019,Data2018, Data2017, Data2016, Data2015, Data2014, Data2013)

  
def plotData( Data): 
    width_in_inches = 20
    height_in_inches = 15
    dots_per_inch = 70
    
    Data2019,Data2018, Data2017, Data2016, Data2015, Data2014, Data2013 = Data
    
    Data2019,Data2018, Data2017, Data2016, Data2015, Data2014, Data2013 = Data2019[::-1],Data2018[::-1], Data2017[::-1], Data2016[::-1], Data2015[::-1], Data2014[::-1], Data2013[::-1]
    
    fig, axs = plt.subplots(3,3 , figsize=(width_in_inches, height_in_inches), dpi=dots_per_inch)
    fig.suptitle('Time series')
    
    if len(Data2019) > 0:

        axs[(0, 0)].plot(np.array(Data2019)[:,0], np.array(Data2019)[:,1])
        axs[0, 0].set_title('Year 2019')
        axs[0, 0].set_xlabel('Average price ')
        axs[0, 0].set_ylabel('Time')
        axs[0,0].xaxis.set_visible(True)
        axs[0,0].yaxis.set_visible(True)
        axs[0,0].set_xticklabels(np.array(Data2019)[:,0], rotation=80)
    
    if len(Data2018) > 0:

        axs[0, 1].plot(np.array(Data2018)[:,0], np.array(Data2018)[:,1], 'tab:orange')
        axs[0, 1].set_title('Year 2018')
        axs[0, 1].set_xlabel('Average price ')
        axs[0, 1].set_ylabel('Time')
        axs[0, 1].xaxis.set_visible(True)
        axs[0, 1].yaxis.set_visible(True)
        axs[0, 1].set_xticklabels(np.array(Data2018)[:,0], rotation=80)

    if len(Data2017) > 0:
        axs[1, 0].plot(np.array(Data2017)[:,0], np.array(Data2017)[:,1], 'tab:green')
        axs[1, 0].set_title('Data2017')
        axs[1, 0].set_xlabel('Average price ')
        axs[1, 0].set_ylabel('Time')
        axs[1, 0].xaxis.set_visible(True)
        axs[1, 0].yaxis.set_visible(True)
        axs[1, 0].grid(True)
        axs[1, 0].set_xticklabels(np.array(Data2017)[:,0], rotation=80)
    
    if len(Data2016) > 0:
        axs[1, 1].plot(np.array(Data2016)[:,0], np.array(Data2016)[:,1], 'tab:red')
        axs[1, 1].set_title('Data2016')
        axs[1, 1].set_xlabel('Average price ')
        axs[1, 1].set_ylabel('Time')
        axs[1, 1].xaxis.set_visible(True)
        axs[1, 1].yaxis.set_visible(True)
        axs[1, 1].grid(True)
        axs[1, 1].set_xticklabels(np.array(Data2016)[:,0], rotation=80)
  
    if len(Data2015) > 0:
        axs[2, 0].plot(np.array(Data2015)[:,0], np.array(Data2015)[:,1], 'tab:red')
        axs[2, 0].set_title('Data2015')
        axs[2, 0].set_xlabel('Average price ')
        axs[2, 0].set_ylabel('Time')
        axs[2, 0].xaxis.set_visible(True)
        axs[2, 0].yaxis.set_visible(True)
        axs[2, 0].grid(True)
        axs[2, 0].set_xticklabels(np.array(Data2015)[:,0], rotation=80)

    if len(Data2014) > 0:
        axs[2, 1].plot(np.array(Data2014)[:,0], np.array(Data2014)[:,1], 'tab:red')
        axs[2, 1].set_title('Data2014')
        axs[2, 1].set_xlabel('Average price ')
        axs[2, 1].set_ylabel('Time')
        axs[2, 1].xaxis.set_visible(True)
        axs[2, 1].yaxis.set_visible(True)
        axs[2, 1].grid(True)
        axs[2, 1].set_xticklabels(np.array(Data2014)[:,0], rotation=80)
    
    if len(Data2013) > 0:
        axs[1, 2].plot(np.array(Data2013)[:,0], np.array(Data2013)[:,1], 'tab:red')
        axs[1, 2].set_title('Data2013')
        axs[1, 2].set_xlabel('Average price ')
        axs[1, 2].set_ylabel('Time')
        axs[1, 2].xaxis.set_visible(True)
        axs[1, 2].yaxis.set_visible(True)
        axs[1, 2].grid(True)
        axs[1, 2].set_xticklabels(np.array(Data2013)[:,0], rotation=80)

    # #axs.xticks(rotation=90)
    fig.tight_layout()
    plt.show()

# %%
def displayTimeSeriesData( districtName, marketName, commodityName):
  district = selectByDistrict(districtName)
  districtMarket = selectDistrictMarkets(district, marketName )
  districtMarketCommodity = selectDistrictMarketsCommodity(districtMarket, commodityName)
  data = getDataPerYear(districtMarketCommodity)
  plotData(data)

# %%
displayTimeSeriesData('Nyamasheke','Gaseke','Inyama-zinka')

# %%
gicumbi = selectByDistrict('gicumbi')

# %%
GasekeMarket = selectDistrictMarkets(gicumbi, 'Gaseke')

GasekeMarketInyamaZinka = selectDistrictMarketsCommodity(GasekeMarket, 'Inyama-zinka')

# %%
data = getDataPerYear(GasekeMarketInyamaZinka)

# %%
plotData(data)

# %%
esokoDistrictGicumbiMarkets[1]

# %%
esokoDistrictGicumbiGaseke['Average Price']
width_in_inches = 30
height_in_inches = 25
dots_per_inch = 100
plt.figure(
figsize=(width_in_inches, height_in_inches),
dpi=dots_per_inch)
plt.plot(esokoDistrictGicumbiGaseke['Commodity'], esokoDistrictGicumbiGaseke['Average Price'], 'ro');
plt.grid(True)
# Tweak spacing to prevent clipping of tick-labels
plt.subplots_adjust(bottom=0.2)
plt.xticks(rotation=85)
plt.xlabel('commodities ', fontsize=20)
plt.ylabel('Average prices', fontsize=20)
plt.title('Plot for Gicumbi Disrict commodities', fontsize=20)
plt.show()

# %%
esokoDistrictGicumbiGasekeCommodityList = esokoDistrictGicumbiGaseke['Commodity'].unique().tolist()
esokoDistrictGicumbiGasekeByCommodity = esokoDistrictGicumbiGaseke.set_index("Commodity")

# %%
#esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Date']
width_in_inches = 30
height_in_inches = 25
dots_per_inch = 100
plt.figure(
figsize=(width_in_inches, height_in_inches),
dpi=dots_per_inch)

Data2019 = []
Data2018 = []
Data2017 = []
Data2016 = []
Data2015 = []
Data2014 = []
Data2013 = []

for i in range(len(esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Average Price'])):
    if esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Date'].values[i].find('2019') != -1:
        Data2019.append([esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Date'].values[i], esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Average Price'].values[i] ])
    
    elif esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Date'].values[i].find('2018') != -1:
        Data2018.append([esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Date'].values[i], esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Average Price'].values[i] ]) 
    
    elif esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Date'].values[i].find('2017') != -1:
        Data2017.append([esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Date'].values[i], esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Average Price'].values[i] ])
    
    elif esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Date'].values[i].find('2016') != -1:
        Data2016.append([esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Date'].values[i], esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Average Price'].values[i] ])
    
    elif esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Date'].values[i].find('2015') != -1:
        Data2015.append([esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Date'].values[i], esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Average Price'].values[i] ])
    
    elif esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Date'].values[i].find('2014') != -1:
        Data2014.append([esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Date'].values[i], esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Average Price'].values[i] ])
    
    elif esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Date'].values[i].find('2013') != -1:
        Data2013.append([esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Date'].values[i], esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Average Price'].values[i] ])
        
#     plt.plot(esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Date'], esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Average Price'])
#     plt.subplots_adjust(bottom=0.2)
#     plt.xticks(rotation=85)
#     plt.show()

# %%
np.array(Data2014)[:,1]

# %%
import numpy as np
import matplotlib.pyplot as plt


width_in_inches = 15
height_in_inches = 10
dots_per_inch = 70
#plt.figure(
# figsize=(width_in_inches, height_in_inches),
# dpi=dots_per_inch)

# plt.plot(np.array(Data2014)[:,0], np.array(Data2014)[:,1]);
# plt.grid(True)
# # Tweak spacing to prevent clipping of tick-labels
# plt.subplots_adjust(bottom=0.2)
# plt.xticks(rotation=85)
# plt.xlabel('commodities ', fontsize=20)
# plt.ylabel('Average prices', fontsize=20)
# plt.title('Plot for Gicumbi Disrict commodities', fontsize=20)

plt.figure(
figsize=(width_in_inches, height_in_inches),
dpi=dots_per_inch)
fig, axs = plt.subplots(2, 2, figsize=(width_in_inches, height_in_inches), dpi=dots_per_inch)
fig.suptitle('Time series')

axs[(0, 0)].plot(np.array(Data2019)[:,0], np.array(Data2019)[:,1])
axs[0, 0].set_title('Data2019')
axs[0, 0].set_xlabel('Average price ')
axs[0, 0].set_ylabel('Time')
axs[0,0].xaxis.set_visible(True)
axs[0,0].yaxis.set_visible(True)
axs[0,0].grid(True)
axs[0,0].set_xticklabels(np.array(Data2019)[:,0], rotation=80)


axs[0, 1].plot(np.array(Data2018)[:,0], np.array(Data2018)[:,1], 'tab:orange')
axs[0, 1].set_title('Data2018')
axs[0, 1].xaxis.set_visible(True)
axs[0, 1].yaxis.set_visible(True)

# axs[1, 0].plot(np.array(Data2017)[:,0], np.array(Data2017)[:,1], 'tab:green')
# axs[1, 0].set_title('Data2017')
# axs[1, 0].xaxis.set_visible(True)
# axs[1, 0].yaxis.set_visible(True)

# #axs[1, 1].plot(np.array(Data2016)[:,0], np.array(Data2016)[:,1], 'tab:red')
# #axs[1, 1].set_title('Data2016')

# #axs[2, 0].plot(np.array(Data2015)[:,0], np.array(Data2015)[:,1], 'tab:red')
# #axs[2, 0].set_title('Data2015')

# axs[2, 1].plot(np.array(Data2014)[:,0], np.array(Data2014)[:,1], 'tab:red')
# axs[2, 1].set_title('Data2014')
# axs[2, 1].xaxis.set_visible(True)
# axs[2, 1].yaxis.set_visible(True)

# axs[1, 2].plot(np.array(Data2013)[:,0], np.array(Data2013)[:,1], 'tab:red')
# axs[1, 2].set_title('Data2013')
# axs[1, 2].xaxis.set_visible(True)
# axs[1, 2].yaxis.set_visible(True)

# #axs.xticks(rotation=90)
fig.tight_layout()
# #plt.xticks(rotation=90)
# plt.subplots_adjust(hspace=0.5)
# for tick in axs.get_xticklabels():
#     tick.set_rotation(45)
plt.show()

# %%
np.array(Data2019)[:,1]

# %%
import itertools
for i, j in zip(range(3), itertools.cycle((1, 0))):
  print(i, j)

# %%
esokoDistrictGicumbiGasekeByCommodity
esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Date'].values.reshape(-1,1)

# %%
#for commodity in esokoDistrictGicumbiGasekeCommodityList:
    #print(esokoDistrictGicumbiGasekeByCommodity.loc[str(commodity)])
#esokoDistrictGicumbiGasekeByCommodity
width_in_inches = 30
height_in_inches = 25
dots_per_inch = 100
plt.figure(
figsize=(width_in_inches, height_in_inches),
dpi=dots_per_inch)
plt.plot(esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Date'], esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']['Average Price'])
plt.subplots_adjust(bottom=0.2)
plt.xticks(rotation=85)
plt.show()

# %%
esokoDistrictGicumbiGasekeByCommodity.loc['Inyama-zinka']

# %%
width_in_inches = 30
height_in_inches = 25
dots_per_inch = 100
plt.figure(
figsize=(width_in_inches, height_in_inches),
dpi=dots_per_inch)
plt.plot(esokoDistrictGicumbiGaseke['Commodity'], esokoDistrictGicumbiGaseke['Average Price'], 'ro');
plt.grid(True)
# Tweak spacing to prevent clipping of tick-labels
plt.subplots_adjust(bottom=0.2)
plt.xticks(rotation=85)
plt.xlabel('commodities ', fontsize=20)
plt.ylabel('Average prices', fontsize=20)
plt.title('Plot for Gicumbi Disrict commodities', fontsize=20)
plt.show()

# %%
max(esokoDistrictGicumbiGaseke['Average Price'])

# %%
esokoDistrictGicumbiGaseke

# %%
len(commodity_data)

# %%
esokoByDate = pd.read_csv('esoko.csv', index_col = 'Date')
esoko
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-ae4450ae27dd> in <module>()
#       1 esokoByDate = pd.read_csv('esoko.csv', index_col = 'Date')
# ----> 2 esoko
#
# NameError: name 'esoko' is not defined

# %%
date1 = esokoByDate.loc['06/21/2019']
data2 = date1.set_index('District')
#data3 = data2.loc['NYABIHU']
#df3.groupby(['Name', 'Commodity'])['Name'].count().unstack('Abuse/NFF').fillna(0)
data2
# Out:
#           Province   Market                 Commodity  Average Price
# District
# RUSIZI     Western  Kamembe                      Pome         2933.0
# RUSIZI     Western  Kamembe                 Imyumbati          210.0
# RUSIZI     Western  Kamembe                  Amashaza          933.0
# RUSIZI     Western  Kamembe                 Urunyogwe         1100.0
# RUSIZI     Western  Kamembe                    Amashu          183.0
# RUSIZI     Western  Kamembe                  Ibijumba          140.0
# RUSIZI     Western  Kamembe                    Ditane         3000.0
# RUSIZI     Western  Kamembe                      Uree          425.0
# RUSIZI     Western  Kamembe                       NPK          560.0
# RUSIZI     Western  Kamembe                   Amakara        13000.0
# RUSIZI     Western  Kamembe             Ifu-imyumbati          350.0
# RUSIZI     Western  Kamembe               Tungurusumu         1733.0
# RUSIZI     Western  Kamembe                      Dodo          633.0
# RUBAVU     Western   Mahoko                  Amacunga          500.0
# RUBAVU     Western   Mahoko                  Amashaza          700.0
# RUBAVU     Western   Mahoko                Ibinyomoro          800.0
# RUBAVU     Western   Mahoko                 Ubunyobwa         1000.0
# RUBAVU     Western   Mahoko                 Urunyogwe          800.0
# RUBAVU     Western   Mahoko                Ibishyimbo          500.0
# RUBAVU     Western   Mahoko               Ifu-amasaka          350.0
# RUBAVU     Western   Mahoko               Ifu-ibigori          400.0
# RUBAVU     Western   Mahoko                   Igitoki          180.0
# RUBAVU     Western   Mahoko                   Ibirayi          170.0
# RUBAVU     Western   Mahoko       ibitunguru-bitukura          200.0
# RUBAVU     Western   Mahoko         Ibitunguru-umweru          200.0
# RUBAVU     Western   Mahoko                    Karoti          150.0
# RUBAVU     Western   Mahoko                    Amashu          140.0
# GICUMBI   Northern   Byumba                   Amasaka          360.0
# GICUMBI   Northern   Byumba                   Ibigori          300.0
# GICUMBI   Northern   Byumba                 Urunyogwe          850.0
# ...            ...      ...                       ...            ...
# GICUMBI   Northern   Gaseke                    Indimu          333.0
# GICUMBI   Northern   Gaseke                   Ibigori          385.0
# GICUMBI   Northern   Gaseke                    Ingano          500.0
# GICUMBI   Northern   Gaseke             Ifu-imyumbati          237.0
# GICUMBI   Northern   Gaseke  Ifu-ibigori-yo-mumahanga          483.0
# GICUMBI   Northern   Gaseke               Ifu-ibigori          450.0
# GICUMBI   Northern   Gaseke               Ifu-amasaka          417.0
# GICUMBI   Northern   Gaseke                Ifu-ingano          600.0
# GICUMBI   Northern   Gaseke              Umuceli-Asia          850.0
# GICUMBI   Northern   Gaseke                Umuceli-RW          750.0
# GICUMBI   Northern   Gaseke                 Imyumbati          293.0
# GICUMBI   Northern   Gaseke           Ibitoki-inkashi          223.0
# GICUMBI   Northern   Gaseke                   Igitoki          230.0
# GICUMBI   Northern   Gaseke                   Ibirayi          260.0
# GICUMBI   Northern   Gaseke               Tungurusumu         1800.0
# GICUMBI   Northern   Gaseke                  Amashaza         1000.0
# GICUMBI   Northern   Gaseke                    Amashu          250.0
# GICUMBI   Northern   Gaseke               Ibiringanya          333.0
# GICUMBI   Northern   Gaseke                  Beterave          207.0
# GICUMBI   Northern   Gaseke                    Karoti          513.0
# GICUMBI   Northern   Gaseke                   Imiteja          360.0
# GICUMBI   Northern   Gaseke                  Puwavuro          217.0
# GICUMBI   Northern   Gaseke                    Sereli          313.0
# GICUMBI   Northern   Gaseke       ibitunguru-bitukura          433.0
# GICUMBI   Northern   Gaseke         Ibitunguru-umweru          297.0
# GICUMBI   Northern   Gaseke                    Isombe          223.0
# GICUMBI   Northern   Gaseke                      Dodo          303.0
# GICUMBI   Northern   Gaseke                    Puwaro          717.0
# GICUMBI   Northern   Gaseke                  Urusenda          567.0
# GICUMBI   Northern   Gaseke                   Inyanya          750.0
#
# [1126 rows x 4 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

df2 = df.groupby(['Name', 'Abuse/NFF'])['Name'].count().unstack('Abuse/NFF').fillna(0)
df2[['abuse','nff']].plot(kind='bar', stacked=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-c54ef9a0d7bd> in <module>()
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 df2 = df.groupby(['Name', 'Abuse/NFF'])['Name'].count().unstack('Abuse/NFF').fillna(0)
#       5 df2[['abuse','nff']].plot(kind='bar', stacked=True)
#
# NameError: name 'df' is not defined

# %%
Dates_data = esoko['Date'].unique().tolist()

# %%
Dates_data

# %%
esoko['Date'].loc[Dates_data[0]]

# %%
UnProcessed = np.array(Dates_data).reshape(-1,1)
print(UnProcessed.shape)
Outpout1 = []
Outpout2 = []
for item in Dates_data:
    data = item.split(' ')
    Outpout1.append(data[0])
    Outpout2.append(data[1])

# %%
Dates_data[1]

# %%
UnProcessed[-2:]

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0.0, 1.0 + 0.01, 0.01)
s = np.cos(2 * 2*np.pi * t)
t[41:60] = np.nan

plt.subplot(3, 1, 1)
plt.plot(t, s, '-', lw=2)

plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.title('A sine wave with a gap of NaNs between 0.4 and 0.6')
plt.grid(True)

plt.subplot(3, 1, 2)
t[0] = np.nan
t[-1] = np.nan
plt.plot(t, s, '-', lw=2)
plt.title('Also with NaN in first and last point')

plt.xlabel('time (s)')
plt.ylabel('more nans')
plt.grid(True)

plt.subplot(3, 1, 3)
t[0] = np.nan
t[-1] = np.nan
plt.plot(t, s, '-', lw=2)
plt.title('Also with NaN in first and last point')

plt.xlabel('time (s)')
plt.ylabel('more nans')
plt.grid(True)

plt.tight_layout()
plt.show()
